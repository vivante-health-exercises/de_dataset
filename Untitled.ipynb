# %%
import pandas as pd

# %%
# !ls
# Out:
# Untitled.ipynb            metadata_nhanes.csv       raw_data_nhanes_final.csv

# %%
meta_df = pd.read_csv("metadata_nhanes.csv")
data_df = pd.read_csv("raw_data_nhanes_final.csv")

# %%
meta_df.head()
# Out:
#   original_column_name      new_column_name  \
# 0                 SEQN                   id
# 1             RIAGENDR               gender
# 2             RIDAGEYR                  age
# 3             RIDRETH3       race_ethnicity
# 4             DMQMILIZ  active_duty_veteran
#
#                                             metadata  \
# 0  https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/DEM...
# 1  https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/DEM...
# 2  https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/DEM...
# 3  https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/DEM...
# 4  https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/DEM...
#
#                                          description
# 0                         Respondent sequence number
# 1                               1 = Male; 2 = Female
# 2  Age in years of the participant at the time of...
# 3  1 = Mexican American; 2 = Other Hispanic; 3 = ...
# 4       1 = Yes; 2 = No; 7 = Refused; 9 = Don't Know

# %%
data_df.head()
# Out:
#       id  special_diet  weight_loss_diet  low_fat_diet  low_salt_diet  \
# 0  73557           2.0               NaN           NaN            NaN
# 1  73558           2.0               NaN           NaN            NaN
# 2  73559           1.0               NaN           NaN            NaN
# 3  73560           2.0               NaN           NaN            NaN
# 4  73561           1.0               NaN           NaN            NaN
#
#    low_sugar_diet  low_fiber_diet  drqsdt6  diabetic_diet  gluten_free_diet  \
# 0             NaN             NaN      NaN            NaN               NaN
# 1             NaN             NaN      NaN            NaN               NaN
# 2             NaN             NaN      NaN            7.0               NaN
# 3             NaN             NaN      NaN            NaN               NaN
# 4             NaN             NaN      NaN            NaN               NaN
#
#    ...  routine_healthcare_place  preferred_healthcare_place  \
# ...
